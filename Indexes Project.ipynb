# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd
import pymongo
import datetime

# %%
url='https://finance.yahoo.com/quote/%5EIXIC/history/'

# %%
tables = pd.read_html(url)
tables
# Out:
# [                                                  Date  \
#  0                                         May 15, 2020
#  1                                         May 14, 2020
#  2                                         May 13, 2020
#  3                                         May 12, 2020
#  4                                         May 11, 2020
#  ..                                                 ...
#  96                                        Dec 27, 2019
#  97                                        Dec 26, 2019
#  98                                        Dec 24, 2019
#  99                                        Dec 23, 2019
#  100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                    Open  \
#  0                                              8839.99
#  1                                              8788.04
#  2                                              9006.05
#  3                                              9225.15
# ...

# %%
#NASDAQ Composite (^IXIC)
#Nasdaq GIDS - Nasdaq GIDS Real Time Price. Currency in USD
#Add to watchlist

#Quote Lookup

#8,634.52+139.77 (+1.65%)
#At close: April 24 5:15PM EDT

# %%
tables[0]
# Out:
#                                                   Date  \
# 0                                         May 15, 2020
# 1                                         May 14, 2020
# 2                                         May 13, 2020
# 3                                         May 12, 2020
# 4                                         May 11, 2020
# ..                                                 ...
# 96                                        Dec 27, 2019
# 97                                        Dec 26, 2019
# 98                                        Dec 24, 2019
# 99                                        Dec 23, 2019
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   Open  \
# 0                                              8839.99
# 1                                              8788.04
# 2                                              9006.05
# 3                                              9225.15
# ...

# %%
#Stocks=[Apple,Microsoft, Amazon,Google,Facebook,Alibaba,Cisco,Intel,Oracle,Netflix]

# %%
url2='https://www.macrotrends.net/1320/nasdaq-historical-chart'

# %%
tables2 = pd.read_html(url2)
tables2
# Out:
# [   NASDAQ Composite - Historical Annual Data                                 \
#                                          Year AverageClosing Price Year Open
#  0                                       2020              8681.75   9092.19
#  1                                       2019              7940.36   6665.94
#  2                                       2018              7425.96   7006.90
#  3                                       2017              6235.30   5429.08
#  4                                       2016              4987.79   4903.09
#  5                                       2015              4945.55   4726.81
#  6                                       2014              4375.10   4143.07
#  7                                       2013              3541.29   3112.26
#  8                                       2012              2965.74   2648.72
#  9                                       2011              2677.44   2691.52
# ...

# %%
Dataframe=tables2[0]
Dataframe
# Out:
#    NASDAQ Composite - Historical Annual Data                                 \
#                                         Year AverageClosing Price Year Open
# 0                                       2020              8681.75   9092.19
# 1                                       2019              7940.36   6665.94
# 2                                       2018              7425.96   7006.90
# 3                                       2017              6235.30   5429.08
# 4                                       2016              4987.79   4903.09
# 5                                       2015              4945.55   4726.81
# 6                                       2014              4375.10   4143.07
# 7                                       2013              3541.29   3112.26
# 8                                       2012              2965.74   2648.72
# 9                                       2011              2677.44   2691.52
# ...

# %%
NASDAQ_Short=Dataframe.loc[(Dataframe['NASDAQ Composite - Historical Annual Data']['Year'] >= 2000) & (Dataframe['NASDAQ Composite - Historical Annual Data']['Year'] <= 2020)]
NASDAQ_Short
# Out:
#    NASDAQ Composite - Historical Annual Data                                 \
#                                         Year AverageClosing Price Year Open
# 0                                       2020              8681.75   9092.19
# 1                                       2019              7940.36   6665.94
# 2                                       2018              7425.96   7006.90
# 3                                       2017              6235.30   5429.08
# 4                                       2016              4987.79   4903.09
# 5                                       2015              4945.55   4726.81
# 6                                       2014              4375.10   4143.07
# 7                                       2013              3541.29   3112.26
# 8                                       2012              2965.74   2648.72
# 9                                       2011              2677.44   2691.52
# ...

# %%
NASDAQ_Short.dtypes
# Out:
# NASDAQ Composite - Historical Annual Data  Year                      int64
#                                            AverageClosing Price    float64
#                                            Year Open               float64
#                                            Year High               float64
#                                            Year Low                float64
#                                            Year Close              float64
#                                            Annual% Change           object
# dtype: object

# %%
NASDAQ_Short.columns
# Out:
# MultiIndex([('NASDAQ Composite - Historical Annual Data', ...),
#             ('NASDAQ Composite - Historical Annual Data', ...),
#             ('NASDAQ Composite - Historical Annual Data', ...),
#             ('NASDAQ Composite - Historical Annual Data', ...),
#             ('NASDAQ Composite - Historical Annual Data', ...),
#             ('NASDAQ Composite - Historical Annual Data', ...),
#             ('NASDAQ Composite - Historical Annual Data', ...)],
#            )

# %%
NASDAQ_Short.to_csv('NASDAQ_INDEX_20years.csv')

# %%
# overwriting data after changing format 
#Data_Frame["Date"]= pd.to_datetime(Data_Frame["Date"])

# %%
Dataframe.dtypes
# Out:
# NASDAQ Composite - Historical Annual Data  Year                      int64
#                                            AverageClosing Price    float64
#                                            Year Open               float64
#                                            Year High               float64
#                                            Year Low                float64
#                                            Year Close              float64
#                                            Annual% Change           object
# dtype: object

# %%
df['Year']= pd.to_datetime(df['Year'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-d0113652d60d> in <module>
# ----> 1 df['Year']= pd.to_datetime(df['Year'])
#
# NameError: name 'df' is not defined

# %%
url2='https://www.macrotrends.net/1319/dow-jones-100-year-historical-chart'

# %%
tables3 = pd.read_html(url2)
tables3
# Out:
# [    Dow Jones Industrial Average - Historical Annual Data  \
#                                                       Year
#  0                                                 2020
#  1                                                 2019
#  2                                                 2018
#  3                                                 2017
#  4                                                 2016
#  ..                                                 ...
#  101                                               1919
#  102                                               1918
#  103                                               1917
#  104                                               1916
#  105                                               1915
#
#                                                                     \
#      AverageClosing Price Year Open Year High  Year Low Year Close
#  0               25503.45  28868.80  29551.42  18591.93   23685.42
# ...

# %%
Data_Frame2=tables3[0]
Data_Frame2
# Out:
#     Dow Jones Industrial Average - Historical Annual Data  \
#                                                      Year
# 0                                                 2020
# 1                                                 2019
# 2                                                 2018
# 3                                                 2017
# 4                                                 2016
# ..                                                 ...
# 101                                               1919
# 102                                               1918
# 103                                               1917
# 104                                               1916
# 105                                               1915
#
#                                                                    \
#     AverageClosing Price Year Open Year High  Year Low Year Close
# 0               25503.45  28868.80  29551.42  18591.93   23685.42
# ...

# %%
DJIA_Short=Data_Frame2.loc[(Data_Frame2['Dow Jones Industrial Average - Historical Annual Data']['Year'] >= 2000) & (Data_Frame2['Dow Jones Industrial Average - Historical Annual Data']['Year'] <= 2020)]
DJIA_Short
# Out:
#    Dow Jones Industrial Average - Historical Annual Data                       \
#                                                     Year AverageClosing Price
# 0                                                2020                25503.45
# 1                                                2019                26379.55
# 2                                                2018                25046.86
# 3                                                2017                21750.20
# 4                                                2016                17927.11
# 5                                                2015                17587.03
# 6                                                2014                16777.69
# 7                                                2013                15009.52
# 8                                                2012                12966.44
# 9                                                2011                11957.57
# ...

# %%
DJIA_Short.to_csv('DJIA_INDEX_20years.csv')

# %%
url3='https://www.macrotrends.net/2324/sp-500-historical-chart-data'

# %%
tables4 = pd.read_html(url3)
tables4
# Out:
# [   S&P 500 Index - Historical Annual Data                                 \
#                                       Year AverageClosing Price Year Open
#  0                                    2020              2968.12   3257.85
#  1                                    2019              2913.36   2510.03
#  2                                    2018              2746.21   2695.81
#  3                                    2017              2449.08   2257.83
#  4                                    2016              2094.65   2012.66
#  ..                                    ...                  ...       ...
#  88                                   1932                 6.92      7.82
#  89                                   1931                13.66     15.85
#  90                                   1930                21.00     21.18
#  91                                   1929                26.19     24.81
#  92                                   1928                19.94     17.76
#
#
# ...

# %%
DF=tables4[0]
DF
# Out:
#    S&P 500 Index - Historical Annual Data                                 \
#                                      Year AverageClosing Price Year Open
# 0                                    2020              2968.12   3257.85
# 1                                    2019              2913.36   2510.03
# 2                                    2018              2746.21   2695.81
# 3                                    2017              2449.08   2257.83
# 4                                    2016              2094.65   2012.66
# ..                                    ...                  ...       ...
# 88                                   1932                 6.92      7.82
# 89                                   1931                13.66     15.85
# 90                                   1930                21.00     21.18
# 91                                   1929                26.19     24.81
# 92                                   1928                19.94     17.76
#
#
# ...

# %%
SP_Short=DF.loc[(DF['S&P 500 Index - Historical Annual Data']['Year'] >= 2000) & (DF['S&P 500 Index - Historical Annual Data']['Year'] <= 2020)]
SP_Short
# Out:
#    S&P 500 Index - Historical Annual Data                                 \
#                                      Year AverageClosing Price Year Open
# 0                                    2020              2968.12   3257.85
# 1                                    2019              2913.36   2510.03
# 2                                    2018              2746.21   2695.81
# 3                                    2017              2449.08   2257.83
# 4                                    2016              2094.65   2012.66
# 5                                    2015              2061.07   2058.20
# 6                                    2014              1931.38   1831.98
# 7                                    2013              1643.80   1462.42
# 8                                    2012              1379.61   1277.06
# 9                                    2011              1267.64   1271.87
# 10                                   2010              1139.97   1132.99
# ...

# %%
DF.columns
# Out:
# MultiIndex([('S&P 500 Index - Historical Annual Data',                 'Year'),
#             ('S&P 500 Index - Historical Annual Data', 'AverageClosing Price'),
#             ('S&P 500 Index - Historical Annual Data',            'Year Open'),
#             ('S&P 500 Index - Historical Annual Data',            'Year High'),
#             ('S&P 500 Index - Historical Annual Data',             'Year Low'),
#             ('S&P 500 Index - Historical Annual Data',           'Year Close'),
#             ('S&P 500 Index - Historical Annual Data',       'Annual% Change')],
#            )

# %%
SP_Short.to_csv('S&P_INDEX_20years.csv')

# %%
DF['S&P 500 Index - Historical Annual Data']['Year']
# Out:
# 0     2020
# 1     2019
# 2     2018
# 3     2017
# 4     2016
#       ...
# 88    1932
# 89    1931
# 90    1930
# 91    1929
# 92    1928
# Name: Year, Length: 93, dtype: int64

# %%
Data_Frame2.columns
# Out:
# MultiIndex([('Dow Jones Industrial Average - Historical Annual Data', ...),
#             ('Dow Jones Industrial Average - Historical Annual Data', ...),
#             ('Dow Jones Industrial Average - Historical Annual Data', ...),
#             ('Dow Jones Industrial Average - Historical Annual Data', ...),
#             ('Dow Jones Industrial Average - Historical Annual Data', ...),
#             ('Dow Jones Industrial Average - Historical Annual Data', ...),
#             ('Dow Jones Industrial Average - Historical Annual Data', ...)],
#            )

# %%
Dataframe.columns
# Out:
# MultiIndex([('NASDAQ Composite - Historical Annual Data', ...),
#             ('NASDAQ Composite - Historical Annual Data', ...),
#             ('NASDAQ Composite - Historical Annual Data', ...),
#             ('NASDAQ Composite - Historical Annual Data', ...),
#             ('NASDAQ Composite - Historical Annual Data', ...),
#             ('NASDAQ Composite - Historical Annual Data', ...),
#             ('NASDAQ Composite - Historical Annual Data', ...)],
#            )

# %%
 # Dependencies
import matplotlib.pyplot as plt
import numpy as np

# %%
y_list = ['Year Close', 'Year Open', 'Year High', 'Year Low', 'AverageClosing Price']
c_list = ['blue', 'red', 'yellow', 'orange', 'green']
l_list = ['Close', 'Open', 'High Value', 'Low Value', 'Average Price']
plt.figure(figsize = [10,8])
for y, c, l in zip(y_list, c_list, l_list):
    plt.plot(SP_Short['S&P 500 Index - Historical Annual Data']['Year'], SP_Short['S&P 500 Index - Historical Annual Data'][y], color = c, label = l)
    plt.xticks(np.arange(2000, 2020, step=2))
    plt.xlabel("Last 20 years")
    plt.ylabel("Index_Values")
    plt.title("S&P_INDEX")
    plt.legend()
    plt.savefig("S&P_Index.png")

# %%
y_list = ['Year Close', 'Year Open', 'Year High', 'Year Low', 'AverageClosing Price']
c_list = ['blue', 'red', 'yellow', 'orange', 'green']
l_list = ['Close', 'Open', 'High Value', 'Low Value', 'Average Price']
plt.figure(figsize = [10,8])
for y, c, l in zip(y_list, c_list, l_list):
    plt.plot(NASDAQ_Short['NASDAQ Composite - Historical Annual Data']['Year'], NASDAQ_Short['NASDAQ Composite - Historical Annual Data'][y], color = c, label = l)
    plt.xticks(np.arange(2000, 2020, step=2))
    plt.xlabel("Last 20 years")
    plt.ylabel("Index_Values")
    plt.title("NASDAQ_INDEX")
    plt.legend()
    plt.savefig("NASDAQ_Index.png")

# %%
y_list = ['Year Close', 'Year Open', 'Year High', 'Year Low', 'AverageClosing Price']
c_list = ['blue', 'red', 'yellow', 'orange', 'green']
l_list = ['Close', 'Open', 'High Value', 'Low Value', 'Average Price']
plt.figure(figsize = [10,8])
for y, c, l in zip(y_list, c_list, l_list):
    plt.plot(DJIA_Short['Dow Jones Industrial Average - Historical Annual Data']['Year'], DJIA_Short['Dow Jones Industrial Average - Historical Annual Data'][y], color = c, label = l)
    plt.xticks(np.arange(2000, 2020, step=2))
    plt.xlabel("Last 20 years")
    plt.ylabel("Index_Values")
    plt.title("DJIA_INDEX")
    plt.legend()
    plt.savefig("DJIA_Index.png")

# %%
plt.figure(figsize=[10,8])
plt.plot(NASDAQ_Short['NASDAQ Composite - Historical Annual Data']['Year'],NASDAQ_Short['NASDAQ Composite - Historical Annual Data']['Year Close'], color="blue", label="Close" )
plt.plot(NASDAQ_Short['NASDAQ Composite - Historical Annual Data']['Year'],NASDAQ_Short['NASDAQ Composite - Historical Annual Data']['Year Open'], color="red", label="Open" )
plt.plot(NASDAQ_Short['NASDAQ Composite - Historical Annual Data']['Year'],NASDAQ_Short['NASDAQ Composite - Historical Annual Data']['Year High'], color="yellow", label="High Value" )
plt.plot(NASDAQ_Short['NASDAQ Composite - Historical Annual Data']['Year'],NASDAQ_Short['NASDAQ Composite - Historical Annual Data']['Year Low'], color="orange", label="Low Value" )
plt.plot(NASDAQ_Short['NASDAQ Composite - Historical Annual Data']['Year'],NASDAQ_Short['NASDAQ Composite - Historical Annual Data']['AverageClosing Price'], color="green", label="Average Price" )
plt.xticks(np.arange(2000, 2020, step=2))
plt.xlabel("Last 20 years")
plt.ylabel("Index Values")
plt.title("NASDAQ_INDEX")
plt.legend()
plt.legend()
plt.savefig("NASDAQ_Index.png")

# %%
plt.figure(figsize=[10,8])
plt.plot(DJIA_Short['Dow Jones Industrial Average - Historical Annual Data']['Year'],DJIA_Short['Dow Jones Industrial Average - Historical Annual Data']['Year Close'], color="blue", label="Close" )
plt.plot(DJIA_Short['Dow Jones Industrial Average - Historical Annual Data']['Year'],DJIA_Short['Dow Jones Industrial Average - Historical Annual Data']['Year Open'], color="red", label="Open" )
plt.plot(DJIA_Short['Dow Jones Industrial Average - Historical Annual Data']['Year'],DJIA_Short['Dow Jones Industrial Average - Historical Annual Data']['Year High'], color="yellow", label="High Value" )
plt.plot(DJIA_Short['Dow Jones Industrial Average - Historical Annual Data']['Year'],DJIA_Short['Dow Jones Industrial Average - Historical Annual Data']['Year Low'], color="orange", label="Low Value" )
plt.plot(DJIA_Short['Dow Jones Industrial Average - Historical Annual Data']['Year'],DJIA_Short['Dow Jones Industrial Average - Historical Annual Data']['AverageClosing Price'], color="green", label="Average Price" )
plt.xticks(np.arange(2000, 2020, step=2))
plt.xlabel("Last 20 years")
plt.ylabel("Index Values")
plt.title("DJIA_INDEX")
plt.legend()
plt.legend()
plt.savefig("DJIA_INDEX.png")

# %%
plt.figure(figsize=[10,8])
plt.plot(SP_Short['S&P 500 Index - Historical Annual Data']['Year'],SP_Short['S&P 500 Index - Historical Annual Data']['Year Close'], color="blue", label="Close" )
plt.plot(SP_Short['S&P 500 Index - Historical Annual Data']['Year'],SP_Short['S&P 500 Index - Historical Annual Data']['Year Open'], color="red", label="Open" )
plt.plot(SP_Short['S&P 500 Index - Historical Annual Data']['Year'],SP_Short['S&P 500 Index - Historical Annual Data']['Year High'], color="yellow", label="High Value" )
plt.plot(SP_Short['S&P 500 Index - Historical Annual Data']['Year'],SP_Short['S&P 500 Index - Historical Annual Data']['Year Low'], color="orange", label="Low Value" )
plt.plot(SP_Short['S&P 500 Index - Historical Annual Data']['Year'],SP_Short['S&P 500 Index - Historical Annual Data']['AverageClosing Price'], color="green", label="Average Price" )
plt.xticks(np.arange(2000, 2020, step=2))
plt.xlabel("Last 20 years")
plt.ylabel("Index Values")
plt.title("S&P_INDEX")
plt.legend()
plt.legend()
plt.savefig("S&P_INDEX.png")
